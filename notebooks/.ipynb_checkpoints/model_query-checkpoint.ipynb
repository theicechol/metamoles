# %%
import rdkit
from rdkit import Chem
from rdkit.Chem import Draw
from rdkit.Chem.EState import Fingerprinter
from rdkit.Chem import Descriptors
from rdkit.Chem import rdFMCS
from rdkit.Chem.rdmolops import RDKFingerprint
from rdkit.Chem.Fingerprints import FingerprintMols
from rdkit import DataStructs
from rdkit.Avalon.pyAvalonTools import GetAvalonFP
import numpy as np
import pandas as pd
import pubchempy as pc

# %%
def get_similarity(a,b):
    return DataStructs.FingerprintSimilarity(a, b, metric=DataStructs.TanimotoSimilarity)

def user_input_to_smiles(input_cid):
    """Takes a PubChem CID input and outputs the associated SMILES."""
    for compound in pc.get_compounds(input_cid):
        return compound.isomeric_smiles

# import ellie's function 
def input_to_compound(PubChemCID:str, master_df:pd.DataFrame):
    """
    input_to_compound() calculates the distance from input compound to 
        all products and create a new column. 
    Additionally, calculates the average distance between input compound
    and products for each promiscuous enzyme. 
    
    
    Args: 
        PubChemSID (str): contains PubChemSID to be queried
        master_df (pd.Dataframe): pre-calculated model dataframe 
               
    Returns:
        pd.Dataframe: master_df with two new columns 
        1) that contains distance from input compound to all products
        2) that contains avg distance from input compound to products for each promiscuous enzyme
    """
    
    input_SMILES = user_input_to_smiles(PubChemCID) #Ellie's function 
    input_fingerprint = FingerprintMols.FingerprintMol(Chem.rdmolfiles.MolFromSmiles(input_SMILES))
    dist_from_input = []
    avg_dist_from_input = []
    
    #get individual distance between input and all compounds 
    for i in master_df['Fingerprint']:
        dist_from_input.append(get_similarity(i,input_fingerprint))
    
    
    
    #get average distance between input and compounds for each promiscuous enzyme 
    for entry in np.unique(master_df['entry']):
        #filter dataframe with same enzyme 
        enzyme_split = master_df[master_df['entry']==entry]
        number_of_compounds = len(enzyme_split)
        total_distance = 0 
        
        for j in enzyme_split['Fingerprint']:
            total_distance += get_similarity(j,input_fingerprint)
        #get the average distance
        avg_distance = total_distance/number_of_compounds
        #create a list that contains number of compounds 
        avg_list = [avg_distance]*number_of_compounds
        avg_dist_from_input += avg_list 
        
        
    
    master_df['dist_from_input'] = dist_from_input 
    master_df['avg_dist_from_input'] = avg_dist_from_input 
    
    return master_df

# %%
input_to_compound(243, master_df)
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# <ipython-input-17-018292755fd0> in <module>()
# ----> 1 input_to_compound(243, master_df)
#
# <ipython-input-16-75a58c9e34ef> in input_to_compound(PubChemCID, master_df)
#      33     #get individual distance between input and all compounds
#      34     for i in master_df['Fingerprint']:
# ---> 35         dist_from_input.append(get_similarity(i,input_fingerprint))
#      36
#      37
#
# <ipython-input-16-75a58c9e34ef> in get_similarity(a, b)
#       1 def get_similarity(a,b):
# ----> 2     return DataStructs.FingerprintSimilarity(a, b, metric=DataStructs.TanimotoSimilarity)
#       3
#       4 def user_input_to_smiles(input_cid):
#       5     """Takes a PubChem CID input and outputs the associated SMILES."""
#
# ~\Miniconda3\lib\site-packages\rdkit\DataStructs\__init__.py in FingerprintSimilarity(fp1, fp2, metric)
#      37
#      38   """
# ---> 39   sz1 = fp1.GetNumBits()
#      40   sz2 = fp2.GetNumBits()
#      41   if sz1 < sz2:
#
# AttributeError: 'str' object has no attribute 'GetNumBits'

# %%
master_df = pd.read_csv("../datasets/MASTER_DF.csv")
df.head(10)
# Out:
#         entry product  reacts    PubChem                   SMILES  \
# 0  1.14.99.46  C20232     1.0  163311975  C/C(=C/NC(=O)N)/C(=O)OO
# 1   3.5.1.110  C20232     1.0  163311975  C/C(=C/NC(=O)N)/C(=O)OO
# 2  1.14.99.46  C00178     1.0       3478         CC1=CNC(=O)NC1=O
# 3   1.17.99.4  C00178     1.0       3478         CC1=CNC(=O)NC1=O
# 4     1.3.1.1  C00178     1.0       3478         CC1=CNC(=O)NC1=O
# 5     2.4.2.2  C00178     1.0       3478         CC1=CNC(=O)NC1=O
# 6  1.14.99.46  C00106     1.0       3406          C1=CNC(=O)NC1=O
# 7    2.4.2.57  C00106     1.0       3406          C1=CNC(=O)NC1=O
# 8   1.17.99.4  C00106     1.0       3406          C1=CNC(=O)NC1=O
# 9     1.3.1.1  C00106     1.0       3406          C1=CNC(=O)NC1=O
#
#                                               Mol  \
# 0  <rdkit.Chem.rdchem.Mol object at 0x1a7c6372b0>
# 1  <rdkit.Chem.rdchem.Mol object at 0x1a7c637300>
# 2  <rdkit.Chem.rdchem.Mol object at 0x1a7c637210>
# 3  <rdkit.Chem.rdchem.Mol object at 0x1a7c637620>
# 4  <rdkit.Chem.rdchem.Mol object at 0x1a7c637670>
# 5  <rdkit.Chem.rdchem.Mol object at 0x1a7c637940>
# 6  <rdkit.Chem.rdchem.Mol object at 0x1a7c6375d0>
# 7  <rdkit.Chem.rdchem.Mol object at 0x1a7c637710>
# 8  <rdkit.Chem.rdchem.Mol object at 0x1a7c637800>
# 9  <rdkit.Chem.rdchem.Mol object at 0x1a7c637a30>
#
#                                          Fingerprint      dist  \
# 0  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.421512
# 1  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.467093
# 2  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.421512
# 3  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.414081
# 4  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.420926
# 5  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.446031
# 6  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.421512
# 7  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.439218
# 8  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.414081
# 9  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.420926
#
#    enzyme_class_1  enzyme_class_2       ...         n_C  n_H  n_O  n_N  n_P  \
# 0               1               0       ...         5.0  8.0  4.0  2.0  0.0
# 1               0               0       ...         5.0  8.0  4.0  2.0  0.0
# 2               1               0       ...         5.0  6.0  2.0  2.0  0.0
# 3               1               0       ...         5.0  6.0  2.0  2.0  0.0
# 4               1               0       ...         5.0  6.0  2.0  2.0  0.0
# 5               0               1       ...         5.0  6.0  2.0  2.0  0.0
# 6               1               0       ...         4.0  4.0  2.0  2.0  0.0
# 7               0               1       ...         4.0  4.0  2.0  2.0  0.0
# 8               1               0       ...         4.0  4.0  2.0  2.0  0.0
# 9               1               0       ...         4.0  4.0  2.0  2.0  0.0
#
#    n_S  n_X  DoU       MW  master_avg_dist
# 0  0.0  0.0  3.0  160.129       71849061.3
# 1  0.0  0.0  3.0  160.129       71849061.3
# 2  0.0  0.0  4.0  126.115       71849061.3
# 3  0.0  0.0  4.0  126.115       71849061.3
# 4  0.0  0.0  4.0  126.115       71849061.3
# 5  0.0  0.0  4.0  126.115       71849061.3
# 6  0.0  0.0  4.0  112.088       71849061.3
# 7  0.0  0.0  4.0  112.088       71849061.3
# 8  0.0  0.0  4.0  112.088       71849061.3
# 9  0.0  0.0  4.0  112.088       71849061.3
#
# [10 rows x 25 columns]

# %%
# this dataframe does not makes sense! but I just wanted to see my above function works! 
master_avg_dist = []
for entry in np.unique(df.entry):
    enzyme_split = df[df['entry']==entry]
    number_of_compounds = len(enzyme_split)
    distance = 0 
    for j in enzyme_split['PubChem']:
        distance += j 
    avgdist = distance/number_of_compounds
    avgdistlist = [avgdist]*number_of_compounds
    master_avg_dist += avgdistlist

df['master_avg_dist'] = master_avg_dist
    
df
# Out:
#             entry product  reacts    PubChem  \
# 0      1.14.99.46  C20232     1.0  163311975
# 1       3.5.1.110  C20232     1.0  163311975
# 2      1.14.99.46  C00178     1.0       3478
# 3       1.17.99.4  C00178     1.0       3478
# 4         1.3.1.1  C00178     1.0       3478
# 5         2.4.2.2  C00178     1.0       3478
# 6      1.14.99.46  C00106     1.0       3406
# 7        2.4.2.57  C00106     1.0       3406
# 8       1.17.99.4  C00106     1.0       3406
# 9         1.3.1.1  C00106     1.0       3406
# 10        2.4.2.2  C00106     1.0       3406
# 11     1.14.99.46  C01847     1.0       4964
# 12     1.14.14.33  C01847     1.0       4964
# 13     1.14.14.30  C01847     1.0       4964
# 14     1.14.14.21  C01847     1.0       4964
# 15     1.14.99.46  C20231     1.0  163311974
# 16      3.5.1.110  C20231     1.0  163311974
# 17      2.3.1.224  C00024     1.0       3326
# 18       4.1.3.24  C00024     1.0       3326
# 19        1.3.5.6  C15857     1.0   47205177
# 20        1.3.5.6  C19759     1.0  135626226
# 21        1.3.5.6  C15858     1.0   47205178
# 22      1.21.98.3  C00073     1.0       3373
# 23        2.8.4.5  C00073     1.0       3373
# 24      1.17.98.2  C00073     1.0       3373
# 25        2.8.4.3  C00073     1.0       3373
# 26        2.8.4.4  C00073     1.0       3373
# 27       4.4.1.11  C00073     1.0       3373
# 28      2.1.1.350  C00073     1.0       3373
# 29      2.1.1.192  C00073     1.0       3373
# ...           ...     ...     ...        ...
# 7596      6.2.1.7  C19754     0.0  135626221
# 7597     5.1.1.14  C19754     0.0  135626221
# 7598     4.1.99.2  C00041     0.0       3343
# 7599    2.3.1.261  C00041     0.0       3343
# 7600     3.5.99.7  C20967     0.0  318172258
# 7601  1.14.14.150  C06658     0.0       8883
# 7602     2.1.1.63  C06658     0.0       8883
# 7603   1.14.19.36  C16269     0.0   47205577
# 7604    2.1.1.344  C16269     0.0   47205577
# 7605     2.7.7.79  C05414     0.0       7780
# 7606   1.14.15.28  C15992     0.0   47205305
# 7607    2.3.1.219  C15992     0.0   47205305
# 7608    2.4.1.301  C01081     0.0       4319
# 7609     1.7.1.16  C05356     0.0       7733
# 7610      1.5.1.1  C05356     0.0       7733
# 7611     4.1.1.96  C05356     0.0       7733
# 7612     2.6.1.52  C00813     0.0       4071
# 7613    1.1.1.297  C00813     0.0       4071
# 7614    2.1.1.240  C00117     0.0       3417
# 7615   1.14.14.73  C06383     0.0       8619
# 7616      6.5.1.8  C06383     0.0       8619
# 7617     2.4.1.41  C06383     0.0       8619
# 7618     6.2.1.39  C01595     0.0       4750
# 7619     2.5.1.46  C12317     0.0     582707
# 7620    1.1.1.353  C18012     0.0   96024232
# 7621   1.14.19.52  C00927     0.0       4180
C1=C(SC=[N+]1CC2=CN=C(N=C2N)C)CCOP(=O)(O)O
# 7609       CCCCC/C=C\C/C=C\C/C=C\C=C\[C@H](CCCC(=O)O)OO
# 7610       CCCCC/C=C\C/C=C\C/C=C\C=C\[C@H](CCCC(=O)O)OO
# 7611       CCCCC/C=C\C/C=C\C/C=C\C=C\[C@H](CCCC(=O)O)OO
# 7612                                 C1C(=O)NC(=O)NC1=O
# 7613                                 C1C(=O)NC(=O)NC1=O
# 7614         C([C@@H]1[C@H]([C@H](C(O1)O)O)O)OP(=O)(O)O
# 7615                                        C(N)NC(=O)N
# 7616                                        C(N)NC(=O)N
# 7617                                        C(N)NC(=O)N
# 7618                      CCCCC/C=C\C/C=C\CCCCCCCC(=O)O
# 7619                            C[C@H]([C@H](C(=O)O)N)O
# 7620                  C1=C(C=C2C(=C1O)C(=CC(=O)C2=O)O)O
# 7621  C1[C@@H](C(=O)N1[C@H](C2=CC=C(C=C2)O)C(=O)O)NC...
# 7622  C1[C@@H](C(=O)N1[C@H](C2=CC=C(C=C2)O)C(=O)O)NC...
# 7623  CC1=C2C(=CC(=C1)O)CC[C@@](O2)(C)CC/C=C(\C)/CC/...
# 7624  C[C@H]([C@@H](C(=O)O)O)C(=O)SCCNC(=O)CCNC(=O)[...
# 7625                                         C[C@H]1CO1
#
#                                                  Mol  \
# 0     <rdkit.Chem.rdchem.Mol object at 0x1a7c6372b0>
# 1     <rdkit.Chem.rdchem.Mol object at 0x1a7c637300>
# 2     <rdkit.Chem.rdchem.Mol object at 0x1a7c637210>
# 3     <rdkit.Chem.rdchem.Mol object at 0x1a7c637620>
# 4     <rdkit.Chem.rdchem.Mol object at 0x1a7c637670>
# 5     <rdkit.Chem.rdchem.Mol object at 0x1a7c637940>
# 6     <rdkit.Chem.rdchem.Mol object at 0x1a7c6375d0>
# 7     <rdkit.Chem.rdchem.Mol object at 0x1a7c637710>
# 8     <rdkit.Chem.rdchem.Mol object at 0x1a7c637800>
# 9     <rdkit.Chem.rdchem.Mol object at 0x1a7c637a30>
# 10    <rdkit.Chem.rdchem.Mol object at 0x1a7c637a80>
# 11    <rdkit.Chem.rdchem.Mol object at 0x1a7c637b20>
# 12    <rdkit.Chem.rdchem.Mol object at 0x1a7c637bc0>
# 13    <rdkit.Chem.rdchem.Mol object at 0x1a7c637c60>
# 14    <rdkit.Chem.rdchem.Mol object at 0x1a7c637d00>
# 15    <rdkit.Chem.rdchem.Mol object at 0x1a7c637da0>
# 16    <rdkit.Chem.rdchem.Mol object at 0x1a7c637e40>
# 17    <rdkit.Chem.rdchem.Mol object at 0x1a7c637ee0>
# 18    <rdkit.Chem.rdchem.Mol object at 0x1a7c637f80>
# 19    <rdkit.Chem.rdchem.Mol object at 0x1a7c637e90>
# 20    <rdkit.Chem.rdchem.Mol object at 0x1a7c637f30>
# 21    <rdkit.Chem.rdchem.Mol object at 0x1a7c637d50>
# 22    <rdkit.Chem.rdchem.Mol object at 0x1a7c637df0>
# 23    <rdkit.Chem.rdchem.Mol object at 0x1a7d5c6300>
# 24    <rdkit.Chem.rdchem.Mol object at 0x1a7d5c63a0>
# 25    <rdkit.Chem.rdchem.Mol object at 0x1a7d5c6440>
# 26    <rdkit.Chem.rdchem.Mol object at 0x1a7d5c64e0>
# 27    <rdkit.Chem.rdchem.Mol object at 0x1a7d5c6580>
# 28    <rdkit.Chem.rdchem.Mol object at 0x1a7d5c6620>
# 29    <rdkit.Chem.rdchem.Mol object at 0x1a7d5c66c0>
# ...                                              ...
# 7596  <rdkit.Chem.rdchem.Mol object at 0x1a7d70a710>
# 7597  <rdkit.Chem.rdchem.Mol object at 0x1a7d70a7b0>
# 7598  <rdkit.Chem.rdchem.Mol object at 0x1a7d70a850>
# 7599  <rdkit.Chem.rdchem.Mol object at 0x1a7d70a8f0>
# 7600  <rdkit.Chem.rdchem.Mol object at 0x1a7d70a990>
# 7601  <rdkit.Chem.rdchem.Mol object at 0x1a7d70aa30>
# 7602  <rdkit.Chem.rdchem.Mol object at 0x1a7d70aad0>
# 7603  <rdkit.Chem.rdchem.Mol object at 0x1a7d70ab70>
# 7604  <rdkit.Chem.rdchem.Mol object at 0x1a7d70ac10>
# 7605  <rdkit.Chem.rdchem.Mol object at 0x1a7d70acb0>
# 7606  <rdkit.Chem.rdchem.Mol object at 0x1a7d70ad50>
# 7607  <rdkit.Chem.rdchem.Mol object at 0x1a7d70adf0>
# 7608  <rdkit.Chem.rdchem.Mol object at 0x1a7d70ae90>
# 7609  <rdkit.Chem.rdchem.Mol object at 0x1a7d70af30>
# 7610  <rdkit.Chem.rdchem.Mol object at 0x1a7d70ae40>
# 7611  <rdkit.Chem.rdchem.Mol object at 0x1a7d70aee0>
# 7612  <rdkit.Chem.rdchem.Mol object at 0x1a7d70ad00>
# 7613  <rdkit.Chem.rdchem.Mol object at 0x1a7d70ada0>
# 7614  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b2b0>
# 7615  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b350>
# 7616  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b3f0>
# 7617  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b490>
# 7618  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b530>
# 7619  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b5d0>
# 7620  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b670>
# 7621  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b710>
# 7622  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b7b0>
# 7623  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b850>
# 7624  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b8f0>
# 7625  <rdkit.Chem.rdchem.Mol object at 0x1a7d70b990>
#
#                                             Fingerprint      dist  \
# 0     <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.421512
# 1     <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.467093
# 2     <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.421512
# 3     <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.414081
# 4     <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.420926
# 5     <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.446031
# 6     <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.421512
# 7     <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.439218
# 8     <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.414081
# 9     <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.420926
# 10    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.446031
# 11    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.421512
# 12    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.426619
# 13    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.404514
# 14    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.415769
# 15    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.421512
# 16    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.467093
# 17    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.462790
# 18    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.688164
# 19    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.970696
# 20    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.970696
# 21    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.970696
# 22    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.421676
# 23    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.328125
# 24    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.328125
# 25    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.328125
# 26    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.328125
# 27    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.257773
# 28    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.394355
# 29    <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.328125
# ...                                                 ...       ...
# 7596  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.391673
# 7597  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.384627
# 7598  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.368766
# 7599  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.238706
# 7600  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.327085
# 7601  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.283422
# 7602  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.414489
# 7603  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.423872
# 7604  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.359549
# 7605  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.332359
# 7606  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.391844
# 7607  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.373685
# 7608  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.384065
# 7609  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.337823
# 7610  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.227154
# 7611  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.409311
# 7612  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.340968
# 7613  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.343716
# 7614  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.345320
# 7615  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.366901
# 7616  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.352255
# 7617  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.459055
# 7618  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.366500
# 7619  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.434485
# 7620  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.366303
# 7621  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.260661
# 7622  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.367706
# 7623  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.327011
# 7624  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.353287
# 7625  <rdkit.DataStructs.cDataStructs.ExplicitBitVec...  0.283552
#
#       enzyme_class_1  enzyme_class_2       ...          n_C   n_H   n_O  n_N  \
# 0                  1               0       ...          5.0   8.0   4.0  2.0
# 1                  0               0       ...          5.0   8.0   4.0  2.0
# 2                  1               0       ...          5.0   6.0   2.0  2.0
# 3                  1               0       ...          5.0   6.0   2.0  2.0
# 4                  1               0       ...          5.0   6.0   2.0  2.0
# 5                  0               1       ...          5.0   6.0   2.0  2.0
# 6                  1               0       ...          4.0   4.0   2.0  2.0
# 7                  0               1       ...          4.0   4.0   2.0  2.0
# 8                  1               0       ...          4.0   4.0   2.0  2.0
# 9                  1               0       ...          4.0   4.0   2.0  2.0
# 10                 0               1       ...          4.0   4.0   2.0  2.0
# 11                 1               0       ...         17.0  23.0   9.0  4.0
# 12                 1               0       ...         17.0  23.0   9.0  4.0
# 13                 1               0       ...         17.0  23.0   9.0  4.0
# 14                 1               0       ...         17.0  23.0   9.0  4.0
# 15                 1               0       ...          4.0   6.0   4.0  2.0
# 16                 0               0       ...          4.0   6.0   4.0  2.0
# 17                 0               1       ...         23.0  38.0  17.0  7.0
# 18                 0               0       ...         23.0  38.0  17.0  7.0
# 19                 1               0       ...         40.0  60.0   0.0  0.0
# 20                 1               0       ...         40.0  58.0   0.0  0.0
# 21                 1               0       ...         40.0  56.0   0.0  0.0
# 22                 1               0       ...          5.0  11.0   2.0  1.0
# 23                 0               1       ...          5.0  11.0   2.0  1.0
# 24                 1               0       ...          5.0  11.0   2.0  1.0
# 25                 0               1       ...          5.0  11.0   2.0  1.0
# 26                 0               1       ...          5.0  11.0   2.0  1.0
# 27                 0               0       ...          5.0  11.0   2.0  1.0
# 28                 0               1       ...          5.0  11.0   2.0  1.0
# 29                 0               1       ...          5.0  11.0   2.0  1.0
# ...              ...             ...       ...          ...   ...   ...  ...
# 7596               0               0       ...         15.0  24.0   0.0  0.0
# 7597               0               0       ...         15.0  24.0   0.0  0.0
# 7598               0               0       ...          3.0   7.0   2.0  1.0
# 7599               0               1       ...          3.0   7.0   2.0  1.0
# 7600               0               0       ...          7.0  11.0   5.0  3.0
# 7601               1               0       ...          8.0  14.0   4.0  2.0
# 7602               0               1       ...          8.0  14.0   4.0  2.0
# 7603               1               0       ...         15.0  24.0   0.0  0.0
# 7604               0               1       ...         15.0  24.0   0.0  0.0
# 7605               0               1       ...         40.0  62.0   0.0  0.0
# 7606               1               0       ...         27.0  46.0   2.0  0.0
# 7607               0               1       ...         27.0  46.0   2.0  0.0
# 7608               0               1       ...         12.0  18.0   4.0  4.0
# 7609               1               0       ...         20.0  32.0   4.0  0.0
# 7610               1               0       ...         20.0  32.0   4.0  0.0
# 7611               0               0       ...         20.0  32.0   4.0  0.0
# 7612               0               1       ...          4.0   4.0   3.0  2.0
# 7613               1               0       ...          4.0   4.0   3.0  2.0
# 7614               0               1       ...          5.0  11.0   8.0  0.0
# 7615               1               0       ...          2.0   7.0   1.0  3.0
# 7616               0               0       ...          2.0   7.0   1.0  3.0
# 7617               0               1       ...          2.0   7.0   1.0  3.0
# 7618               0               0       ...         18.0  32.0   2.0  0.0
# 7619               0               1       ...          4.0   9.0   3.0  1.0
# 7620               1               0       ...         10.0   6.0   5.0  0.0
# 7621               1               0       ...         23.0  24.0   9.0  4.0
# 7622               0               1       ...         23.0  24.0   9.0  4.0
# 7623               1               0       ...         27.0  40.0   2.0  0.0
# 7624               0               1       ...         26.0  42.0  20.0  7.0
# 7625               0               0       ...          3.0   6.0   1.0  0.0
#
#       n_P  n_S  n_X   DoU       MW  master_avg_dist
# 0     0.0  0.0  0.0   3.0  160.129     7.184906e+07
# 1     0.0  0.0  0.0   3.0  160.129     7.184906e+07
# 2     0.0  0.0  0.0   4.0  126.115     7.184906e+07
# 3     0.0  0.0  0.0   4.0  126.115     7.184906e+07
# 4     0.0  0.0  0.0   4.0  126.115     7.184906e+07
# 5     0.0  0.0  0.0   4.0  126.115     7.184906e+07
# 6     0.0  0.0  0.0   4.0  112.088     7.184906e+07
