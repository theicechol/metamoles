# %% [markdown]
# The purpose of this notebook is to read the full enzyme database into a notebook, and to begin to explore promiscuous enzymes, and how to pull data on linked reactions

# %%
# imports

from Bio.KEGG import REST
from Bio.KEGG import Enzyme
from Bio.KEGG import Compound

import gzip
import pandas as pd
import numpy as np
import matplotlib as mpl
import matplotlib.pyplot as plt
import seaborn as sns
import re

# %%
# function to read data directly from the text file instead

def enzyme_records_to_df(file_path):
    """
    Input should be a filepath string pointing to a gzipped text file of KEGG enzyme records.
    Function parses all records using Biopython.Bio.KEGG.Enzyme parser, and returns a pandas dataframe.
    """
    enzyme_fields = [method for method in dir(Enzyme.Record()) if not method.startswith('_')]
    data_matrix = []

    with gzip.open(file_path, 'rt') as file:
        for record in Enzyme.parse(file):
            data_matrix.append([getattr(record, field) for field in enzyme_fields])
    
    enzyme_df = pd.DataFrame(data_matrix, columns=enzyme_fields)
    return enzyme_df

# %%
# read in enzyme data

enzyme_df = enzyme_records_to_df('../datasets/KEGG_enzymes_all_data.gz')

# %%
enzyme_df.shape
# Out:
# (7524, 16)

# %%
enzyme_df.head()
# Out:
#                                            classname cofactor  \
# 0  [Oxidoreductases;, Acting on the CH-OH group o...       []
# 1  [Oxidoreductases;, Acting on the CH-OH group o...       []
# 2  [Oxidoreductases;, Acting on the CH-OH group o...       []
# 3  [Oxidoreductases;, Acting on the CH-OH group o...       []
# 4  [Oxidoreductases;, Acting on the CH-OH group o...       []
#
#                                              comment  \
# 0  [A zinc protein. Acts on primary or secondary ...
# 1  [A zinc protein. Some members of this group ox...
# 2  [The yeast enzyme acts most rapidly with NAD+;...
# 3  [Also converts diacetyl into acetoin with NADH...
# 4  [Transferred entry: acetoin dehydrogenase. Now...
#
#                                              dblinks disease effector  \
# 0  [(ExplorEnz - The Enzyme Database, [1.1.1.1]),...      []       []
# 1  [(ExplorEnz - The Enzyme Database, [1.1.1.2]),...      []       []
# 2  [(ExplorEnz - The Enzyme Database, [1.1.1.3]),...      []       []
# 3  [(ExplorEnz - The Enzyme Database, [1.1.1.4]),...      []       []
# 4                                                 []      []       []
#
#      entry                                              genes inhibitor  \
# 0  1.1.1.1  [(HSA, [124, 125, 126, 127, 128, 130, 131]), (...        []
# 1  1.1.1.2  [(HSA, [10327]), (PTR, [741418]), (PPS, [10099...        []
# 2  1.1.1.3  [(NVE, [NEMVE_v1g225948]), (ATH, [AT1G31230, A...        []
# 3  1.1.1.4  [(SCE, [YAL060W, YAL061W]), (KLA, [KLLA0_F0050...        []
# 4  1.1.1.5                                                 []        []
#
#                                                 name  \
# 0  [alcohol dehydrogenase, aldehyde reductase, AD...
# 1  [alcohol dehydrogenase (NADP+), aldehyde reduc...
# 2              [homoserine dehydrogenase, HSDH, HSD]
# 3  [(R,R)-butanediol dehydrogenase, butyleneglyco...
# 4           [Transferred to 1.1.1.303 and 1.1.1.304]
#
#                                              pathway  \
# 0  [(PATH, ec00010, Glycolysis / Gluconeogenesis)...
# 1  [(PATH, ec00010, Glycolysis / Gluconeogenesis)...
# 2  [(PATH, ec00260, Glycine, serine and threonine...
# 3            [(PATH, ec00650, Butanoate metabolism)]
# 4                                                 []
#
#                                              product  \
# 0  [aldehyde [CPD:C00071], NADH [CPD:C00004], H+ ...
# 1  [aldehyde [CPD:C00071], NADPH [CPD:C00005], H+...
# 2  [L-aspartate 4-semialdehyde [CPD:C00441], NADH...
# 3  [(R)-acetoin [CPD:C00810], NADH [CPD:C00004], ...
# 4                                                 []
#
#                                             reaction structures  \
# 0  [(1) a primary alcohol + NAD+ = an aldehyde + ...         []
# 1  [an alcohol + NADP+ = an aldehyde + NADPH + H+...         []
# 2  [L-homoserine + NAD(P)+ = L-aspartate 4-semial...         []
# 3  [(R,R)-butane-2,3-diol + NAD+ = (R)-acetoin + ...         []
# 4                                                 []         []
#
#                                            substrate  \
# 0  [primary alcohol [CPD:C00226], NAD+ [CPD:C0000...
# 1         [alcohol [CPD:C00069], NADP+ [CPD:C00006]]
# 2  [L-homoserine [CPD:C00263], NAD+ [CPD:C00003],...
# 3  [(R,R)-butane-2,3-diol [CPD:C03044], NAD+ [CPD...
# 4                                                 []
#
#                                        sysname
# 0                [alcohol:NAD+ oxidoreductase]
# 1               [alcohol:NADP+ oxidoreductase]
# 2        [L-homoserine:NAD(P)+ oxidoreductase]
# 3  [(R,R)-butane-2,3-diol:NAD+ oxidoreductase]
# 4                                           []

# %%
# apply a boolean mask to the dataframe to select only rows in which the number of reaction entries is > 1

promiscuous_df = enzyme_df[[True if len(rxn) > 1 else False for rxn in enzyme_df['reaction']]]

# %%
# how many promiscuous enzymes are there?

promiscuous_df.shape
# Out:
# (549, 16)

# %%
# histogram of total reactions per enzyme EC category

reactions = [len(rxn) for rxn in promiscuous_df['reaction']]

hist = sns.distplot(reactions, bins=20, kde=False, norm_hist=False)

# %%
# example product field

prod_example = enzyme_df.iloc[0]['product']
prod_example
# Out:
# ['aldehyde [CPD:C00071]',
#  'NADH [CPD:C00004]',
#  'H+ [CPD:C00080]',
#  'ketone [CPD:C01450]']

# %%
# test pull CPD record from KEGG
# note: this doesn't appear to work if CPD is in caps

cpd_entry_71 = (REST.kegg_get('cpd:c00071').read())

# %%
cpd_entry_71
# Out:
# 'ENTRY       C00071                      Compound\nNAME        Aldehyde;\n            RCHO\nFORMULA     CHOR\nCOMMENT     Generic compound in reaction hierarchy\nREACTION    R00538 R00544 R00623 R00625 R00631 R00634 R00635 R00636 \n            R00637 R00638 R00639 R01409 R01853 R01854 R02745 R03415 \n            R07158 R07210 R07326 R07328 R08372 R09359 R09480 R10388 \n            R10713 R10911 R10912 R11354\nPATHWAY     map00071  Fatty acid degradation\nENZYME      1.1.1.1         1.1.1.2         1.1.1.71        1.1.2.7         \n            1.1.3.13        1.1.9.1         1.1.99.20       1.2.1.3         \n            1.2.1.4         1.2.1.5         1.2.3.1         1.2.5.2         \n            1.2.7.5         1.2.99.6        1.2.99.7        1.4.3.4         \n            1.4.3.21        1.7.3.1         1.14.14.5       3.3.2.2         \n            4.1.1.1         4.1.2.10        4.1.2.11        4.1.2.47\nDBLINKS     PubChem: 3371\n            ChEBI: 17478\nATOM        3\n            1   C4a C    22.1200  -16.5003\n            2   O4a O    23.3312  -15.7981\n            3   R   R    20.9088  -15.7981\nBOND        2\n            1     1   2 2\n            2     1   3 1\n///\n'

# %%
# fiddle with regex to get CPD number

prod_example.append('[cpd:c00071]')

regex = '\[CPD:(C\d{5})]'
print(re.findall(regex, str(prod_example), re.IGNORECASE))
# Out:
# ['C00071', 'C00004', 'C00080', 'C01450', 'c00071']

# %%
prod_example
# Out:
# ['aldehyde [CPD:C00071]',
#  'NADH [CPD:C00004]',
#  'H+ [CPD:C00080]',
#  'ketone [CPD:C01450]',
#  '[cpd:c00071]']

# %%
# function that extracts list of KEGG compound IDs from product or substrate field of enzyme entry
# regex reference: https://regex101.com/

# changed this to leave out the brackets
def extract_KEGG_compound_IDs(field):
    """
    This function uses regular expressions to extract the KEGG compound IDs from a product or substrate field
    in an enzyme record (or other KEGG record)
    """
    
    cpd_list = []
    regex = 'CPD:(C\d+)'    # matches '[CPD: ' characters exactly, captures 'C' + any number of digits (\d+), befor another literal ']' character
    for entry in field:
        ids = re.findall(regex, str(entry), re.IGNORECASE)
        for i in ids:
            cpd_list.append(i)
    
    return cpd_list

# %%
# # test out KEGG compound extraction function
# # this works but takes a very long time

# test_df = promiscuous_df[:5]

# test_df['compound_ids'] = test_df['product'].apply(extract_KEGG_compound_IDs)

# test_df

# %%
# try extracting entry, classname, and name for each product compound id, and creating new dataframe


def explode_dataframe(dataframe, explosion_function, explosion_target_field, fields_to_include):
    """
    This function applies the input explosion_function to the target field in each row of a dataframe.
    Each item in the output of the explosion_function is an anchor for a new row in the new dataframe.
    All of the supplied fields_to_include are added to the explosion item, and appended to the new dataframe row.
    
    dataframe, 
    explosion_function, 
    explosion_target_field, 
    fields_to_include
    """
    
    new_rows = []
    for _, row in dataframe.iterrows():
        explosion_list = explosion_function(row[explosion_target_field])
        for item in explosion_list:
            row_data = [row[field] for field in fields_to_include]
            row_data.append(item)
            new_rows.append(row_data)

    fields_to_include.append(explosion_target_field)
    new_df = pd.DataFrame(new_rows, columns=fields_to_include)
    
    return new_df

# %%
# # test explode_dataframe function

# new_test_df = explode_dataframe(test_df, extract_KEGG_compound_IDs, 'product', ['entry', 'name'])

# new_test_df

# %%
# run explode dataframe function on full promiscuous enzyme dataframe

expanded_prom_enzymes_df = explode_dataframe(promiscuous_df, extract_KEGG_compound_IDs, 'product', ['entry'])

# %%
# looks like a total of 1878 product compound/enzyme pairs

expanded_prom_enzymes_df.head()
# Out:
#      entry product
# 0  1.1.1.1  C00071
# 1  1.1.1.1  C00004
# 2  1.1.1.1  C00080
# 3  1.1.1.1  C01450
# 4  1.1.1.1  c00071

# %%
# no empty cells - this is good

expanded_prom_enzymes_df.isnull().sum()
# Out:
# entry      0
# product    0
# dtype: int64

# %% [markdown]
# ## Starting work here

# %%
expanded_prom_enzymes_df.shape
# Out:
# (1879, 2)

# %%
#cofactor removal 
cofactor_df = pd.read_csv("../datasets/cofactor_list.csv")
cofactor_list = extract_KEGG_compound_IDs(cofactor_df['CPD'])
len(cofactor_list)
# Out:
# 37

# %%
# remove rows that contain cofactors

bool_mask = [False if cpd in cofactor_list else True for cpd in expanded_prom_enzymes_df['product']]
clean_enzyme_df = expanded_prom_enzymes_df[bool_mask]

# %%
clean_enzyme_df.shape
# Out:
# (1221, 2)

# %%
# one duplicate enzyme - compound entry 

deduplicated = clean_enzyme_df.drop_duplicates()
deduplicated.shape
# Out:
# (1220, 2)

# %%
clean_enzyme_df.head()
# Out:
#       entry product
# 0   1.1.1.1  C00071
# 3   1.1.1.1  C01450
# 4   1.1.1.1  c00071
# 5  1.1.1.38  C00022
# 8  1.1.1.40  C00022

# %%
# check PubChem id number lengths & for empty cells
# looks like there are some empty fields, as well as some longer id numbers
# we should look into these more, but for now I will charge ahead

def check_length_dist(dataframe, field):
    id_lengths = [len(data) for data in dataframe[field]]

    values, counts = np.unique(id_lengths, return_counts=True)

    for i in range(len(values)):
        print("{}: {}".format(values[i], counts[i]))

    print("\ntotal numbers: {}\ncdataframe shape: {}".format(counts.sum(), dataframe.shape))

# %%
check_length_dist(clean_enzyme_df, 'entry')
# Out:
# 7: 131
# 8: 377
# 9: 342
# 10: 266
# 11: 105
#
# total numbers: 1221
# cdataframe shape: (1221, 2)

# %%
# function to create two dataframes - one of positive data (enzyme - compound pairs that exist in the dataset)
# and one of negative data (all enzyme - compound pairs that do not exist in the dataset)

def neg_data_matchmaker(dataframe, enzyme_field, compound_field):
    """neg_data_matchmaker creates two dataframes. 
    One dataframe is positive data that contains all the enzyme-compound pairs that exist in the dataset
    The second data frame is negative data made from matching all enzyme-compound pairs that do not 
    exist in the dataset.
    
    dataframe: input pandas dataframe
    enzyme_field: string identifier denoting which column contains enzyme ids
    compound_field: string identifier denoting which column contains compound ids
    """
    unique_enzymes = set(dataframe[enzyme_field].unique())
    # set of all unique enzymes in provided dataframes
    unique_cpds = set(dataframe[compound_field].unique())
    # set of all unique compounds in provided dataframe

    positive_data = []
    negative_data = []
    # initialize empty lists

    for enzyme in unique_enzymes:
    # iterate through unique enzyme set
        working_prods = set(dataframe[dataframe[enzyme_field] == enzyme][compound_field].unique())
        # unique set of all products reported to reaction with this enzyme in provided dataset
        non_working_prods = (unique_cpds - working_prods)
        # set math of all remaining products in the dataset minus those reported to react

        reactions = [{'reacts':1.0, 'enzyme':enzyme, 'product':product} for product in working_prods]
        # create new entry for each positive reaction
        non_reactions = [{'reacts':0.0, 'enzyme':enzyme, 'product':product} for product in non_working_prods]
        # create new entry for each negative reaction

        positive_data.extend(reactions)
        # add positive reactions to master list
        negative_data.extend(non_reactions)
        # add negative reactions to master list

    positive_df = pd.DataFrame(positive_data)
    negative_df = pd.DataFrame(negative_data)
    
    return positive_df, negative_df

# %%
pos_df, neg_df = neg_data_matchmaker(clean_enzyme_df, 'entry', 'product')

# %%
neg_df.shape
# Out:
# (424125, 3)

# %%
unique_cpds.remove('C00022')

# %%
len(unique_cpds)
# Out:
# 877

# %%
# function to read compound data from text file directly into dataframe

def compound_records_to_df(file_path):
    """
    Input should be a filepath string pointing to a gzipped text file of KEGG enzyme records.
    Function parses all records using Biopython.Bio.KEGG.Compound parser, and returns a pandas dataframe.
    """
    compound_fields = [method for method in dir(Compound.Record()) if not method.startswith('_')]
    data_matrix = []

    with gzip.open(file_path, 'rt') as file:
        for record in Compound.parse(file):
            data_matrix.append([getattr(record, field) for field in compound_fields])
    
    compound_df = pd.DataFrame(data_matrix, columns=compound_fields)
    return compound_df

# %%
# read in compound data

compound_df = compound_records_to_df('../datasets/KEGG_compound_db_entries.gz')

# %%
# looks like there are 18505 entries

compound_df.shape
# Out:
# (18505, 8)

# %%
compound_df.head()
# Out:
#                                              dblinks   entry  \
# 0  [(CAS, [7732-18-5]), (PubChem, [3303]), (ChEBI...  C00001
# 1  [(CAS, [56-65-5]), (PubChem, [3304]), (ChEBI, ...  C00002
# 2  [(CAS, [53-84-9]), (PubChem, [3305]), (ChEBI, ...  C00003
# 3  [(CAS, [58-68-4]), (PubChem, [3306]), (ChEBI, ...  C00004
# 4  [(CAS, [2646-71-1]), (PubChem, [3307]), (ChEBI...  C00005
#
#                                               enzyme        formula mass  \
# 0  [1.1.1.1, 1.1.1.22, 1.1.1.23, 1.1.1.115, 1.1.1...            H2O
# 1  [1.1.98.6, 1.2.1.30, 1.2.1.95, 1.2.1.101, 1.3....  C10H16N5O13P3
# 2  [1.1.1.1, 1.1.1.3, 1.1.1.4, 1.1.1.6, 1.1.1.7, ...  C21H28N7O14P2
# 3  [1.1.1.1, 1.1.1.3, 1.1.1.4, 1.1.1.6, 1.1.1.7, ...  C21H29N7O14P2
# 4  [1.1.1.1, 1.1.1.2, 1.1.1.3, 1.1.1.10, 1.1.1.19...  C21H30N7O17P3
#
#                                                 name  \
# 0                                       [H2O, Water]
# 1                   [ATP, Adenosine 5'-triphosphate]
# 2  [NAD+, NAD, Nicotinamide adenine dinucleotide,...
# 3  [NADH, DPNH, Reduced nicotinamide adenine dinu...
# 4  [NADPH, TPNH, Reduced nicotinamide adenine din...
#
#                                              pathway structures
# 0  [(PATH, map00190, Oxidative phosphorylation), ...         []
# 1  [(PATH, map00190, Oxidative phosphorylation), ...         []
# 2  [(PATH, map00190, Oxidative phosphorylation), ...         []
# 3  [(PATH, map00190, Oxidative phosphorylation), ...         []
# 4  [(PATH, map00195, Photosynthesis), (PATH, map0...         []

# %%
compound_df.iloc[0][0]
# Out:
# [('CAS', ['7732-18-5']),
#  ('PubChem', ['3303']),
#  ('ChEBI', ['15377']),
#  ('ChEMBL', ['CHEMBL1098659']),
#  ('PDB-CCD', ['HOH', 'O']),
#  ('3DMET', ['B01124']),
#  ('NIKKAJI', ['J43.587B'])]

# %%
# function to extract PubChem compound ID:

def extract_PubChem_id(field):
    """
    This function uses regular expressions to extract the PubChem compound IDs from a field in a record
    """

    regex = "'PubChem', \[\'(\d+)\'\]\)" # matches "'PubChem', ['" characters exactly, then captures any number of digits (\d+), before another literal "']" character match
    ids = re.findall(regex, str(field), re.IGNORECASE)
    if len(ids) > 0:
        pubchem_id = ids[0]
    else:
        pubchem_id = ''
    
    return pubchem_id

# %%
# extract PubChem compound IDs to a new field in compound dataframe

PubChemID_list = []

for _, row in compound_df.iterrows():
    pubchem_id = extract_PubChem_id(row['dblinks'])
    PubChemID_list.append(pubchem_id)
    
compound_df['PubChem'] = PubChemID_list

# %%
compound_df.head()
# Out:
#                                              dblinks   entry  \
# 0  [(CAS, [7732-18-5]), (PubChem, [3303]), (ChEBI...  C00001
# 1  [(CAS, [56-65-5]), (PubChem, [3304]), (ChEBI, ...  C00002
# 2  [(CAS, [53-84-9]), (PubChem, [3305]), (ChEBI, ...  C00003
# 3  [(CAS, [58-68-4]), (PubChem, [3306]), (ChEBI, ...  C00004
# 4  [(CAS, [2646-71-1]), (PubChem, [3307]), (ChEBI...  C00005
#
#                                               enzyme        formula mass  \
# 0  [1.1.1.1, 1.1.1.22, 1.1.1.23, 1.1.1.115, 1.1.1...            H2O
# 1  [1.1.98.6, 1.2.1.30, 1.2.1.95, 1.2.1.101, 1.3....  C10H16N5O13P3
# 2  [1.1.1.1, 1.1.1.3, 1.1.1.4, 1.1.1.6, 1.1.1.7, ...  C21H28N7O14P2
# 3  [1.1.1.1, 1.1.1.3, 1.1.1.4, 1.1.1.6, 1.1.1.7, ...  C21H29N7O14P2
# 4  [1.1.1.1, 1.1.1.2, 1.1.1.3, 1.1.1.10, 1.1.1.19...  C21H30N7O17P3
#
#                                                 name  \
# 0                                       [H2O, Water]
# 1                   [ATP, Adenosine 5'-triphosphate]
# 2  [NAD+, NAD, Nicotinamide adenine dinucleotide,...
# 3  [NADH, DPNH, Reduced nicotinamide adenine dinu...
# 4  [NADPH, TPNH, Reduced nicotinamide adenine din...
#
#                                              pathway structures PubChem
# 0  [(PATH, map00190, Oxidative phosphorylation), ...         []    3303
# 1  [(PATH, map00190, Oxidative phosphorylation), ...         []    3304
# 2  [(PATH, map00190, Oxidative phosphorylation), ...         []    3305
# 3  [(PATH, map00190, Oxidative phosphorylation), ...         []    3306
# 4  [(PATH, map00195, Photosynthesis), (PATH, map0...         []    3307

# %%
# check PubChem id number lengths & for empty cells
# looks like there are some empty fields, as well as some longer id numbers
# we should look into these more, but for now I will charge ahead

id_lengths = [len(field) for field in compound_df['PubChem']]

values, counts = np.unique(id_lengths, return_counts=True)

for i in range(len(values)):
    print("{}: {}".format(values[i], counts[i]))
    
print("\ntotal numbers: {}\ncompound_df shape: {}".format(counts.sum(), compound_df.shape))
# Out:
# 0: 197
# 4: 5835
# 5: 4198
# 6: 813
# 7: 141
# 8: 3582
# 9: 3739
#
# total numbers: 18505
# compound_df shape: (18505, 9)

# %%
# final step: join compound dataframe onto enzyme dataframe

joint_enzyme_compound_df = expanded_prom_enzymes_df.merge(compound_df, left_on='product', right_on='entry')

# %%
joint_enzyme_compound_df.head()
# Out:
#     entry_x                                             name_x product  \
# 0   1.1.1.1  [alcohol dehydrogenase, aldehyde reductase, AD...  C00071
# 1   3.3.2.2  [lysoplasmalogenase, alkenylglycerophosphochol...  C00071
# 2   1.1.1.1  [alcohol dehydrogenase, aldehyde reductase, AD...  C00004
# 3  1.1.1.38  [malate dehydrogenase (oxaloacetate-decarboxyl...  C00004
# 4  1.1.1.85  [3-isopropylmalate dehydrogenase, beta-isoprop...  C00004
#
#                                              dblinks entry_y  \
# 0              [(PubChem, [3371]), (ChEBI, [17478])]  C00071
# 1              [(PubChem, [3371]), (ChEBI, [17478])]  C00071
# 2  [(CAS, [58-68-4]), (PubChem, [3306]), (ChEBI, ...  C00004
# 3  [(CAS, [58-68-4]), (PubChem, [3306]), (ChEBI, ...  C00004
# 4  [(CAS, [58-68-4]), (PubChem, [3306]), (ChEBI, ...  C00004
#
#                                               enzyme        formula mass  \
# 0  [1.1.1.1, 1.1.1.2, 1.1.1.71, 1.1.2.7, 1.1.3.13...           CHOR
# 1  [1.1.1.1, 1.1.1.2, 1.1.1.71, 1.1.2.7, 1.1.3.13...           CHOR
# 2  [1.1.1.1, 1.1.1.3, 1.1.1.4, 1.1.1.6, 1.1.1.7, ...  C21H29N7O14P2
# 3  [1.1.1.1, 1.1.1.3, 1.1.1.4, 1.1.1.6, 1.1.1.7, ...  C21H29N7O14P2
# 4  [1.1.1.1, 1.1.1.3, 1.1.1.4, 1.1.1.6, 1.1.1.7, ...  C21H29N7O14P2
#
#                                               name_y  \
# 0                                   [Aldehyde, RCHO]
# 1                                   [Aldehyde, RCHO]
# 2  [NADH, DPNH, Reduced nicotinamide adenine dinu...
# 3  [NADH, DPNH, Reduced nicotinamide adenine dinu...
# 4  [NADH, DPNH, Reduced nicotinamide adenine dinu...
#
#                                              pathway structures PubChem
# 0         [(PATH, map00071, Fatty acid degradation)]         []    3371
# 1         [(PATH, map00071, Fatty acid degradation)]         []    3371
# 2  [(PATH, map00190, Oxidative phosphorylation), ...         []    3306
# 3  [(PATH, map00190, Oxidative phosphorylation), ...         []    3306
# 4  [(PATH, map00190, Oxidative phosphorylation), ...         []    3306

# %%
# clean up columns, etc

joint_enzyme_compound_df.drop(['entry_y', 'enzyme', 'pathway', 'structures'], axis=1, inplace=True)

# %%
# rename columns

new_col_names = ['ec_number', 'enzyme_name', 'product_cpd', 'dblinks', 'product_formula', 'product_mass', 'product_name', 'pubchem_id']
new_col_dict = dict(zip(joint_enzyme_compound_df.columns, new_col_names))

joint_enzyme_compound_df.rename(columns=new_col_dict, inplace=True)
joint_enzyme_compound_df.sort_values(by=['ec_number']).head()
# Out:
#     ec_number                                        enzyme_name product_cpd  \
# 0     1.1.1.1  [alcohol dehydrogenase, aldehyde reductase, AD...      C00071
# 2     1.1.1.1  [alcohol dehydrogenase, aldehyde reductase, AD...      C00004
# 93    1.1.1.1  [alcohol dehydrogenase, aldehyde reductase, AD...      C01450
# 33    1.1.1.1  [alcohol dehydrogenase, aldehyde reductase, AD...      C00080
# 5   1.1.1.110  [aromatic 2-oxoacid reductase, (R)-aromatic la...      C00004
#
#                                               dblinks product_formula  \
# 0               [(PubChem, [3371]), (ChEBI, [17478])]            CHOR
# 2   [(CAS, [58-68-4]), (PubChem, [3306]), (ChEBI, ...   C21H29N7O14P2
# 93              [(PubChem, [4627]), (ChEBI, [17087])]            COR2
# 33       [(PubChem, [3380]), (ChEBI, [15378, 24636])]               H
# 5   [(CAS, [58-68-4]), (PubChem, [3306]), (ChEBI, ...   C21H29N7O14P2
#
#    product_mass                                       product_name pubchem_id
# 0                                                 [Aldehyde, RCHO]       3371
# 2                [NADH, DPNH, Reduced nicotinamide adenine dinu...       3306
# 93                                               [Ketone, R-CO-R']       4627
# 33                                                    [H+, Hydron]       3380
# 5                [NADH, DPNH, Reduced nicotinamide adenine dinu...       3306

# %%
# check PubChem id number lengths & empty fields

id_lengths = [len(field) for field in joint_enzyme_compound_df['pubchem_id']]

values, counts = np.unique(id_lengths, return_counts=True)

for i in range(len(values)):
    print("{}: {}".format(values[i], counts[i]))
    
print("\ntotal numbers: {}\ncompound_df shape: {}".format(counts.sum(), joint_enzyme_compound_df.shape))
# Out:
# 0: 54
# 4: 1339
# 5: 61
# 6: 12
# 7: 3
# 8: 117
# 9: 292
#
# total numbers: 1878
# compound_df shape: (1878, 8)

# %%
# examine 0 fields
# looks like these entries don't have a dblink for PubChem
# may be able to deal with these later, but for now we'll just have to move on

bool_mask = [True if length == 0 else False for length in id_lengths]

empty_pubchems = joint_enzyme_compound_df[bool_mask]

empty_pubchems
# Out:
#         ec_number                                        enzyme_name  \
# 503     1.3.1.114  [3-dehydro-bile acid Delta4,6-reductase, baiN ...
# 504     1.3.1.114  [3-dehydro-bile acid Delta4,6-reductase, baiN ...
# 553     1.3.99.37  [1-hydroxy-2-isopentenylcarotenoid 3,4-desatur...
# 910    1.14.14.69              [ent-cassadiene hydroxylase, CYP71Z7]
# 911    1.14.14.69              [ent-cassadiene hydroxylase, CYP71Z7]
# 912    1.14.14.69              [ent-cassadiene hydroxylase, CYP71Z7]
# 913    1.14.14.69              [ent-cassadiene hydroxylase, CYP71Z7]
# 914    1.14.14.71         [cucurbitadienol 11-hydroxylase, CYP87D18]
# 915    1.14.14.71         [cucurbitadienol 11-hydroxylase, CYP87D18]
# 917    1.14.14.73  [albendazole monooxygenase (sulfoxide-forming)...
# 918    1.14.14.76  [ent-isokaurene C2/C3-hydroxylase, CYP71Z6, en...
# 980   1.14.14.159  [dolabradiene monooxygenase, CYP71Z16 (gene na...
# 981   1.14.14.159  [dolabradiene monooxygenase, CYP71Z16 (gene na...
# 982   1.14.14.160       [zealexin A1 synthase, CYP71Z18 (gene name)]
# 983   1.14.14.160       [zealexin A1 synthase, CYP71Z18 (gene name)]
# 984   1.14.14.160       [zealexin A1 synthase, CYP71Z18 (gene name)]
# 986   1.14.14.161  [nepetalactol monooxygenase, CYP76A26 (gene na...
# 989   1.14.14.169              [eupatolide synthase, CYP71DD6, HaES]
# 990   1.14.14.170               [8-epi-inunolide synthase, CYP71BL1]
# 991   1.14.14.170               [8-epi-inunolide synthase, CYP71BL1]
# 1086   1.14.19.55  [4-hydroxybenzoate brominase (decarboxylating)...
# 1087   1.14.19.55  [4-hydroxybenzoate brominase (decarboxylating)...
# 1088   1.14.19.55  [4-hydroxybenzoate brominase (decarboxylating)...
# 1089   1.14.19.59  [tryptophan 6-halogenase, sttH (gene name), th...
# 1090   1.14.19.59  [tryptophan 6-halogenase, sttH (gene name), th...
# 1097   1.14.19.75  [very-long-chain acyl-lipid omega-9 desaturase...
# 1098   1.14.19.75  [very-long-chain acyl-lipid omega-9 desaturase...
# 1099    1.14.20.4  [anthocyanidin synthase, leucocyanidin oxygena...
# 1287    2.1.1.350  [menaquinone C8-methyltransferase, mqnK (gene ...
# 1288    2.1.1.350  [menaquinone C8-methyltransferase, mqnK (gene ...
# 1289      2.1.5.1  [sesamin methylene transferase, sesA (gene name)]
# 1291      2.1.5.1  [sesamin methylene transferase, sesA (gene name)]
# 1323    2.3.1.251  [lipid IVA palmitoyltransferase, PagP, crcA (g...
# 1324    2.3.1.251  [lipid IVA palmitoyltransferase, PagP, crcA (g...
# 1356    2.4.1.195  [N-hydroxythioamide S-beta-glucosyltransferase...
# 1464    2.5.1.148          [lycopaoctaene synthase, LOS (gene name)]
# 1465    2.5.1.149  [lycopene elongase/hydratase (flavuxanthin-for...
# 1466    2.5.1.149  [lycopene elongase/hydratase (flavuxanthin-for...
# 1467    2.5.1.150  [lycopene elongase/hydratase (dihydrobisanhydr...
# 1468    2.5.1.150  [lycopene elongase/hydratase (dihydrobisanhydr...
# 1491    2.6.1.114  [8-demethyl-8-aminoriboflavin-5'-phosphate syn...
# 1492    2.6.1.114  [8-demethyl-8-aminoriboflavin-5'-phosphate syn...
# 1493    2.6.1.114  [8-demethyl-8-aminoriboflavin-5'-phosphate syn...
# 1601      2.8.5.2  [L-cysteine S-thiosulfotransferase, SoxXA, thi...
# 1602      2.8.5.2  [L-cysteine S-thiosulfotransferase, SoxXA, thi...
# 1616    3.1.1.104                 [5-phospho-D-xylono-1,4-lactonase]
# 1617    3.1.1.104                 [5-phospho-D-xylono-1,4-lactonase]
# 1650     3.1.6.20  [S-sulfosulfanyl-L-cysteine sulfohydrolase, SoxB]
# 1652     3.1.6.20  [S-sulfosulfanyl-L-cysteine sulfohydrolase, SoxB]
# 1826     4.4.1.37  [pyridinium-3,5-bisthiocarboxylic acid mononuc...
# 1827     4.4.1.37  [pyridinium-3,5-bisthiocarboxylic acid mononuc...
# 1829     4.4.1.37  [pyridinium-3,5-bisthiocarboxylic acid mononuc...
# 1857     6.2.1.53  [L-proline---[L-prolyl-carrier protein] ligase...
# 1858     6.2.1.55  [E1 SAMP-activating enzyme, UbaA, SAMP-activat...
#
#      product_cpd                                         dblinks  \
# 503       C21906                                              []
# 504       C21908                                              []
# 553       C22059                                              []
# 910       C21826                                              []
# 911       C21827                                              []
# 912       C21828                                              []
# 913       C21829                                              []
# 914       C21841                                              []
# 915       C21842                                              []
# 917       C21882  [(CAS, [53716-50-0]), (ChEMBL, [CHEMBL42442])]
# 918       C21831                                              []
# 980       C22009                                              []
# 981       C22010                                              []
# 982       C22011                                              []
# 983       C22012                                              []
# 984       C22013                                              []
# 986       C22014                                              []
# 989       C22050                                              []
# 990       C22054                                              []
# 991       C22051                                              []
# 1086      C21850                                              []
# 1087      C21852                     [(ChEMBL, [CHEMBL3938214])]
# 1088      C21853                                              []
# 1089      C21866                              [(PDB-CCD, [6CW])]
# 1090      C21867                           [(CAS, [56632-86-1])]
# 1097      C22018                                              []
# 1098      C22020                                              []
# 1099      C21832                                              []
# 1287      C22027                                              []
# 1288      C22028                                              []
# 1289      C21801      [(ChEMBL, [CHEMBL1688934, CHEMBL1688936])]
# 1291      C21802                     [(ChEMBL, [CHEMBL1082870])]
# 1323      C22002                                              []
# 1324      C21982                                              []
# 1356      C21872                                              []
# 1464      C22055                             [(CAS, [502-62-5])]
# 1465      C22056                                              []
# 1466      C22057                                              []
# 1467      C22058                                              []
# 1468      C22060                                              []
# 1491      C21805                                              []
# 1492      C21803                                              []
# 1493      C21804                                              []
# 1601      C21815                                              []
# 1602      C21899                                              []
# 1616      C22035                                              []
# 1617      C22037                                              []
# 1650      C21898                                              []
# 1652      C21814                                              []
# 1826      C21878                                              []
# 1827      C21877                                              []
# 1829      C21879                                              []
# 1857      C20656                              [(PDB-CCD, [PR8])]
# 1858      C21901                                              []
#
#         product_formula product_mass  \
# 503      C45H70N7O18P3S
# 504      C45H70N7O19P3S
# 553             C45H64O
# 910            C20H30O2
# 911             C20H32O
# 912             C20H30O
# 913            C20H32O2
# 914            C30H48O2
# 915            C30H50O2
# 917         C15H13N3O3S
# 918            C20H32O2
# 980             C20H32O
# 981            C20H32O2
# 982            C15H22O2
# 983             C15H24O
# 984             C15H22O
# 986            C10H16O3
# 989            C15H22O4
# 990            C15H20O2
# 991            C15H22O3
# 1086           C7H5BrO3
# 1087          C6H4Br2O2
# 1088           C7H5BrO4
# 1089       C11H11ClN2O2
# 1090       C11H11ClN2O2
# 1097        C30H55O8PR2
# 1098        C28H51O8PR2
# 1099           C15H12O3
# 1287    C17H18O2(C5H8)n
# 1288    C16H16O2(C5H8)n
# 1289           C19H18O6
# 1291           C18H18O6
# 1323     C89H169N3O27P2
# 1324     C84H160N2O24P2
# 1356  C10H19NO6S2(CH2)n
# 1464             C40H66
# 1465            C45H64O
# 1466           C50H72O2
# 1467            C45H66O
# 1468           C50H74O2
# 1491        C16H20N5O9P
# 1492       C17H19N4O10P
# 1493       C17H19N4O11P
# 1601        C3H5NO4S3R2
# 1602        C3H5NO4S4R2
# 1616           C5H11O9P
# 1617           C5H11O9P
# 1650         C3H5NOS2R2
# 1652         C3H5NOS3R2
# 1826       C12H15NO10PS
# 1827      C22H27N6O17P2
# 1829     C22H27N6O16P2S
# 1857        C15H21N6O8P
# 1858       C14H19N7O9PR
#
#                                            product_name pubchem_id
# 503                         [3-Oxochol-4-en-24-oyl-CoA]
# 504         [12alpha-Hydroxy-3-oxochol-4-en-24-oyl-CoA]
# 553                        [Isopentenyldehydrorhodopin]
# 910           [ent-3beta-Hydroxycassa-12,15-dien-2-one]
# 911                     [ent-Cassa-12,15-dien-2beta-ol]
# 912                        [ent-Cassa-12,15-dien-2-one]
# 913            [ent-Cassa-12,15-diene-2beta,3beta-diol]
# 914   [11-Oxocucurbitadienol, 3beta-Hydroxycucurbita...
# 915                         [11-Hydroxycucurbitadienol]
# 917                 [Fenbendazole S-oxide, Oxfendazole]
# 918   [ent-2alpha,3alpha-Dihydroxyisokaurene, ent-Is...
# 980                              [15,16-Epoxydolabrene]
# 981                [3beta-Hydroxy-15,16-epoxydolabrene]
# 982   [Zealexin A1, (4S)-4-(5,5-Dimethylcyclohex-1-e...
# 983   [[(4S)-4-(5,5-Dimethylcyclohex-1-en-1-yl)-cycl...
# 984   [(4S)-4-(5,5-Dimethylcyclohex-1-en-1-yl)cycloh...
# 986                          [7-Deoxyloganetic alcohol]
# 989   [6alpha,8beta-Dihydroxygermacra-1(10),4,11(13)...
# 990   [8-epi-Inunolide, Germacra-1(10),4,11(13)-trie...
# 991   [8alpha-Hydroxygermacra-1(10),4,11(13)-trien-1...
# 1086                        [3-Bromo-4-hydroxybenzoate]
# 1087                      [3,5-Dibromobenzene-1,2-diol]
# 1088                    [3-Bromo-4,5-dihydroxybenzoate]
# 1089                            [6-Chloro-L-tryptophan]
# 1090                            [6-Chloro-D-tryptophan]
# 1097  [1-[(17Z)-Hexacos-17-enoyl]-2-acyl-[phosphogly...
# 1098  [1-[(15Z)-Tetracos-15-enoyl]-2-acyl-[phosphogl...
# 1099                 [(4S)- 2,3-Dehydroflavan-3,4-diol]
# 1287                              [8-Methylmenaquinone]
# 1288                   [2-Demethyl-8-methylmenaquinone]
# 1289      [(+)-Demethylpiperitol, Sesamin monocatechol]
# 1291    [(+)-Didemethylpinoresinol, Sesamin dicatechol]
# 1323                                        [Lipid IIB]
# 1324  [Lipid IVB, 2-Deoxy-2-{[(3R)-3-hydroxytetradec...
# 1356  [Aliphatic desulfoglucosinolate, omega-(Methyl...
# 1464                                    [Lycopaoctaene]
# 1465                                 [Nonaflavuxanthin]
# 1466                                     [Flavuxanthin]
# 1467                [Dihydroisopentenyldehydrorhodopin]
# 1468                 [Dihydrobisanhydrobacterioruberin]
# 1491  [8-Amino-8-demethylriboflavin 5'-phosphate, 8-...
# 1492       [8-Demethyl-8-formylriboflavin 5'-phosphate]
# 1493  [8-Carboxy-8-demethylriboflavin 5'-phosphate, ...
# 1601        [[SoxY protein]-S-sulfosulfanyl-L-cysteine]
# 1602  [[SoxY protein]-S-(2-sulfodisulfanyl)-L-cysteine]
# 1616                             [5-Phospho-D-xylonate]
# 1617   [5-Phospho-L-arabinate, 5-Phospho-L-arabinonate]
# 1650             [[SoxY protein]-S-sulfanyl-L-cysteine]
# 1652           [[SoxY protein]-S-disulfanyl-L-cysteine]
# 1826  [Pyridinium-3-carboxy-5-thiocarboxylic acid mo...
# 1827  [5-Carboxy-1-(5-O-phospho-beta-D-ribofuranosyl...
# 1829  [1-(5-O-Phospho-beta-D-ribofuranosyl)-5-(sulfa...
# 1857                              [(L-Prolyl)adenylate]
# 1858                               [[SAMP]-Gly-Gly-AMP]

# %%
# write to csv file

joint_enzyme_compound_df.to_csv('pubchem_ids_promiscuous_enzyme_products.csv')
